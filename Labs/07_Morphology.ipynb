# %%
# binary land cover map
import rasterio
import matplotlib.pyplot as plt

img = rasterio.open(r"Data\spot2005_pansharpened_utm33_subset_NIRRGMIR.tif")
img_data = img.read(1)

plt.imshow(img_data, cmap='gray')

# %%
img_data.size
# Out:
# 532860
