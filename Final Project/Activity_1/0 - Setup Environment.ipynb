# %% [markdown]
# # Install requirements to run the notebooks
#
# The required Python packages are in `requirements.txt`, you can install them manually or install everything with:

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from -r requirements.txt (line 1)) (3.10.6)
# Requirement already satisfied: numpy in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from -r requirements.txt (line 2)) (2.2.5)
# Requirement already satisfied: tqdm in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from -r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: sap in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from -r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: rasterio in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from -r requirements.txt (line 5)) (1.4.3)
# Requirement already satisfied: ipympl in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from -r requirements.txt (line 6)) (0.9.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from matplotlib->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from tqdm->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: higra in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from sap->-r requirements.txt (line 4)) (0.6.12)
# Requirement already satisfied: affine in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from rasterio->-r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: attrs in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from rasterio->-r requirements.txt (line 5)) (24.3.0)
# Requirement already satisfied: certifi in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from rasterio->-r requirements.txt (line 5)) (2025.11.12)
# Requirement already satisfied: click>=4.0 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from rasterio->-r requirements.txt (line 5)) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from rasterio->-r requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from rasterio->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: ipython<10 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipympl->-r requirements.txt (line 6)) (8.30.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipympl->-r requirements.txt (line 6)) (8.1.8)
# Requirement already satisfied: traitlets<6 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipympl->-r requirements.txt (line 6)) (5.14.3)
# Requirement already satisfied: decorator in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipython<10->ipympl->-r requirements.txt (line 6)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipython<10->ipympl->-r requirements.txt (line 6)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipython<10->ipympl->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipython<10->ipympl->-r requirements.txt (line 6)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipython<10->ipympl->-r requirements.txt (line 6)) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipython<10->ipympl->-r requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipython<10->ipympl->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipython<10->ipympl->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 6)) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 6)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 6)) (3.0.16)
# Requirement already satisfied: wcwidth in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<10->ipympl->-r requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from jedi>=0.16->ipython<10->ipympl->-r requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: six>=1.5 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from stack-data->ipython<10->ipympl->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from stack-data->ipython<10->ipympl->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\ethel ogallo\.conda\envs\lab_ersip\lib\site-packages (from stack-data->ipython<10->ipympl->-r requirements.txt (line 6)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Optional: Install Jupyter Widgets
#
# - <https://ipywidgets.readthedocs.io/en/stable/user_install.html>
#
# ## With pip
#
# ```
# pip install ipywidgets
# ```
#
# ## With Conda
#
# ```
# conda install -c conda-forge ipywidgets
# ```

# %% [markdown]
# # Test widgets

# %%
import ipywidgets as ipw

def f(x):
    return x

ipw.interact(f, x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
